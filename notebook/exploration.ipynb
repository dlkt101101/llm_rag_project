# %% [markdown]
# # Project Exploration: Harnessing Large Language Models (LLMs) and Retrieval-Augmented Generation (RAG) for Context-Aware AI Solutions

# %%
print("Hello World")
# Out:
# Hello World
